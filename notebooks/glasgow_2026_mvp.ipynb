# %% [markdown]
# # Glasgow 2026 Transport Forecast

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ## 3. Methods

# %% [markdown]
# ## 4. Results

# %% [markdown]
# ## 5. Conclusion
